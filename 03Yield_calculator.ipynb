# %% [markdown]
# 이 python 파일은 수익률을 구하기 위한 파일입니다.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('03for_yield_calculator.xlsx',sheet_name = 'Sheet1')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0        7380        3270      431852         NaN         NaN         NaN
# 1        7500        3280      441667         NaN         NaN         NaN
# 2        7350        3180      445593         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 3354  \
# 0         NaN       18991       14300        4680  ...            NaN
# 1         NaN       18991       14500        4700  ...            NaN
# 2         NaN       17540       14650        4630  ...            NaN
#
#    Unnamed: 3355  Unnamed: 3356  Unnamed: 3357  Unnamed: 3358  Unnamed: 3359  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
#
#    Unnamed: 3360  Unnamed: 3361  Unnamed: 3362  Unnamed: 3363
# ...

# %%
df2 = df.pct_change()*100
df2
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1       1.626016    0.305810    2.272769         NaN         NaN         NaN
# 2      -2.000000   -3.048780    0.888905         NaN         NaN         NaN
# 3       1.088435    1.886792    4.405141         NaN         NaN         NaN
# 4      -1.749664   -2.777778    3.375593         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 5119    0.246914    0.685871   -0.374532    0.510204    1.810585   -1.808786
# 5120    0.369458    0.544959    1.503759    1.776650    1.778386    0.789474
# 5121    0.122699    0.406504   -2.222222   -0.374065    0.806452   -2.872063
# 5122    0.735294   -0.134953    1.893939    1.126408    0.800000    1.209677
# 5123   -0.973236   -1.351351   -1.486989   -0.371287    1.587302    0.132802
#
# ...

# %%
df2.to_excel('03Real_yield_calculator.xlsx') # 실행 후 맨 밑 행 삭제하고 날짜 한 칸씩 밀린 것 보정할 것
